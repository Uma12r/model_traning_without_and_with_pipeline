# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass             Name     Sex  ...                                Ticket    Fare  Embarked Survived
# 0            1       3     Allison Hill    male  ...  43d75413-a939-4bd1-a516-b0d47d3572cc  144.08         Q        1
# 1            2       1      Noah Rhodes    male  ...  6334fa2a-8b4b-47e7-a451-5ae01754bf08  249.04         S        0
# 2            3       3  Angie Henderson    male  ...  61a66444-e2af-4629-9efb-336e2f546033   50.31         Q        1
# 3            4       3    Daniel Wagner    male  ...  0b6c03c8-721e-4419-afc3-e6495e911b91  235.20         C        1
# 4            5       1  Cristian Santos  female  ...  436e3c49-770e-49db-b092-d40143675d58  160.17         C        1
#
# [5 rows x 11 columns]

# %%
df.drop(columns=["PassengerId","Name","Ticket"],inplace=True)

# %%
df.head()
# Out:
#    Pclass     Sex  Age  SibSp  Parch    Fare Embarked  Survived
# 0       3    male   17      4      2  144.08        Q         1
# 1       1    male   60      2      2  249.04        S         0
# 2       3    male   64      0      0   50.31        Q         1
# 3       3    male   35      4      0  235.20        C         1
# 4       1  female   70      0      3  160.17        C         1

# %% [raw]
# x_train,x_test,y_train,y_test=train_test_split(df.drop("Survived",axis=1),df["Survived"],test_size=0.2,random_state=0)

# %%
x_train.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
ohe=OneHotEncoder(sparse_output=False,handle_unknown="ignore")

# %%
encoder_x_train_embarked_sex=ohe.fit_transform(x_train[["Sex","Embarked"]])

# %%
encoder_x_test_embarked_sex=ohe.fit_transform(x_test[["Sex","Embarked"]])

# %%
x_train_rem=x_train.drop(columns=["Sex","Embarked"])
x_test_rem=x_test.drop(columns=["Sex","Embarked"])

# %%
x_train_rem
# Out:
#      Pclass  Age  SibSp  Parch    Fare
# 687       1   32      2      2  232.55
# 500       2   74      2      2  411.01
# 332       1   38      3      3  318.61
# 979       3   75      1      2  298.12
# 817       3   73      2      4  204.92
# ..      ...  ...    ...    ...     ...
# 835       3   32      1      4  275.22
# 192       1   55      4      3  207.18
# 629       2   60      4      2  319.87
# 559       1   32      0      3  177.07
# 684       1   60      2      1  341.07
#
# [800 rows x 5 columns]

# %%
x_train_transformed=np.concatenate((x_train_rem,encoder_x_train_embarked_sex),axis=1)

# %%
x_test_transformed=np.concatenate((x_test_rem,encoder_x_test_embarked_sex),axis=1)

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train_transformed,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_preds=clf.predict(x_test_transformed)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_preds)
# Out:
# 0.555

# %%
import pickle

# %%
pickle.dump(ohe,open("ohe_sex_embarked.pkl","wb"))
pickle.dump(clf,open("clf.pkl","wb"))

# %%
x_train.head(2)
# Out:
#      Pclass     Sex  Age  SibSp  Parch    Fare Embarked
# 687       1    male   32      2      2  232.55        S
# 500       2  female   74      2      2  411.01        S

# %%
x_train_transformed.shape
# Out:
# (800, 10)
